# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Prime-Python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_2%EA%B0%95_%EC%8B%A4%EC%8A%B5(%ED%95%99%EC%8A%B5%EC%9E%90%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2강 파이썬 시작! 실습

# %% [markdown]
# ## 2강 3절

# %% [markdown]
# **에코(echo)**

# %%
# "Hello World, Python!"
# 123 * 456 / 789

# %% [markdown]
# **수학식 계산**

# %%
# 25 + 7, 365-31, 52*4, 5/2

# %% [markdown]
# <img src="data:image/png;base64,..." width=150>

# %% [markdown]
# **들여쓰기(indentation)**

# %%
print("파이썬에 오신것을 환영합니다.")

# %% [markdown]
# **주석(comment)**

# %%
print((10.5 + 2 * 3) / (45 – 3.5))
