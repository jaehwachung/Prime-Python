# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Prime-Python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_7%EA%B0%95_%EC%8B%A4%EC%8A%B5(%ED%95%99%EC%8A%B5%EC%9E%90%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #7강 함수

# %% [markdown]
# ##7.1 함수의 이해

# %% [markdown]
# **함수의 정의**

# %%
def sum(nFrom, nTo):


print(f"1부터 10까지의 합은 {summation}입니다.")

# %% [markdown]
# **여러 원의 넓이와 둘레를 반복적으로 계산?**

# %%
def circle_area_circum(r) :

#반지름 사용자 입력
rad = int(input("반지름을 입력하세요: "))

# %%
def circle_area(r) :

#반지름 사용자 입력
rad = int(input("반지름을 입력하세요: "))

circle_area(rad)

# %% [markdown]
# **성적 산출**
#
# ---
#
# <img width=150 src="data:image/png;base64,...">

# %%
score = int(input("점수를 입력하세요: "))

score2grade(score)

# %% [markdown]
# **큰 수 찾기**

# %%
n1 = int(input("첫번째 수를 입력하세요: "))
n2 = int(input("두번째 수를 입력하세요: "))

print(findmax(n1, n2))

# %% [markdown]
# ##7.2 함수의 활용

# %% [markdown]
# **동시 할당**

# %%
width = 30
height = 50

# %% [markdown]
# **교환(swap)**

# %%
temp = rad2
rad2 = rad1
rad1 = temp

# %% [markdown]
# **넓이와 둘레는 동시에 반환?**

# %%
def circle_area_circum(r) :

#반지름 사용자 입력
rad = int(input("반지름을 입력하세요: "))

# %% [markdown]
# ##7.3 함수의 설계

# %% [markdown]
# **기본 파라미터**

# %%
hello("파이썬", "재미있습니다.")

# %% [markdown]
# **가변 파라미터**

# %%
print(f"1, 3, 5, 7, 9의 합은 {num_sum(1, 3, 5, 7, 9)}입니다.")

# %% [markdown]
# **여러 원의 넓이와 둘레를 반복적으로 계산?**

# %%
def circles_area_circum(*rs) :

#반지름
circles_area_circum(1, 3, 5, 7, 9, 11, 13, 17)
