# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Prime-Python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_3%EA%B0%95_%EC%8B%A4%EC%8A%B5(%ED%95%99%EC%8A%B5%EC%9E%90%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #3강 변수와 연산자

# %% [markdown]
# ##3.1 데이터의 저장

# %% [markdown]
# **반지름이 20인 원의 넓이와 둘레 출력은?**
#
# <img width=350 src="data:image/png;base64,...">

# %%
#넓이 출력

#둘레 출력

# %% [markdown]
# **반지름이 40인 원의 넓이와 둘레 출력은?**

# %%
#넓이 출력

#둘레 출력

# %% [markdown]
# **식별자**

# %% [markdown]
# ##3.2 연산자

# %% [markdown]
# **산술 연산자**

# %%
print(2 * 10)
print(5 / 2)

# %% [markdown]
# **문자열 연산자**

# %%
message1 = "파이썬을 "

# %% [markdown]
# **직관적인 표현을 사용한 원 넓이, 둘레 프로그램**

# %%
#반지름값 저장
rad = 40
#넓이 출력
print(rad * rad * 3.141)
#둘레 출력
print(2 * rad * 3.141)

# %% [markdown]
# ##3.3 데이터의 표현

# %% [markdown]
# **print ( ) 함수**

# %%
amount = 12618985
interestRate = 0.013
interest = amount * interestRate
print(interest)

print("이자는", interest, "원 입니다.")

# %% [markdown]
# **f-문자열**

# %%
amount = 12618985
interestRate = 0.013

# %% [markdown]
# **출력값의 의미와 소수점 둘째자리까지만 출력?**
