# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Prime-Python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_9%EA%B0%95_%EC%8B%A4%EC%8A%B5(%ED%95%99%EC%8A%B5%EC%9E%90%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #9강 리스트

# %% [markdown]
# ##9.1 리스트의 이해

# %% [markdown]
# **리스트의 생성과 접근**

# %%
scores = [87, 61, 98, 78, 85]

# %% [markdown]
# **리스트 관련 연산자와 메소드**

# %%
scores1 = [87, 61, 98, 78, 85]
scores2 = [87, 61, 99]

# %% [markdown]
# **유효 평균값과 중앙값 구하기**

# %%
# 점수 리스트
ascore = [9, 8, 10, 7, 9, 8, 10, 6, 9, 8, 7, 9, 10, 8, 9, 5, 8, 9, 7]

# %% [markdown]
# ##9.2 리스트의 활용

# %% [markdown]
# **리스트 슬라이싱**

# %%
scores = [87, 61, 98, 78, 85, 89]

# %% [markdown]
# **리스트 컴프리헨션**

# %%
scores = [87, 61, 98, 78, 85, 89]

# %% [markdown]
# **문자 빈도수 세기 문제**

# %%
close = [
   9200,  10150,   9450,  11080,   9720,
  10430,   9150,  11240,   9860,  11890,
  10320,  12150,   9970,  11580,   9420,
  10960,   9050,  12040,  10010,  12580,
  10820,  11970,   9620,  11360,   9310,
  11190,   9840,  12320,  10180,  12850
]
threshold = 11000
